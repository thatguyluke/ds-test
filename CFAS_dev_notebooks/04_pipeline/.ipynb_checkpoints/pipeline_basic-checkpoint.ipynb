# %% [markdown]
# ## Basic Pipeline Example
#
# This notebook shows how to use basic functions of the Cortex Python SDK pipeline.
# In this example, see how to modify or enrich datasets to make them suitable for training or modeling.
# Data is modified in a sequential series of steps.

# %%
# Import Cortex and other required libraries
import math
import numpy as np
import pandas as pd
from cortex import Cortex

# Create a Builder instance
cortex = Cortex.local()
builder = cortex.builder()

# %% [markdown]
# In the next step, create a data set and populate it from a comma separated values file. A pipeline operates on a dataset.

# %%
dataset_name_ff = input("namespace/dataset name")

data_set = builder.dataset(dataset_name_ff).title('Forest Fire Data')\
    .from_csv('data/ff.sample.csv').build()
# Create a pandas DataFrame to view the last few lines of the dataset
data_frame = data_set.as_pandas()
data_frame.tail(20)
# Out:
# namespace/dataset name surface/forest_fires
#     X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain     area
# 0   7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0     0.00
# 1   7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0     0.00
# 2   7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0     0.00
# 3   8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2     0.00
# 4   8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0     0.00
# 5   8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0     0.00
# 6   8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0     0.00
# 7   8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0     0.00
# 8   8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0     0.00
# 9   3  4   sep  fri  93.3  141.2  713.9  13.9  18.6  49   3.6   0.0    35.88
# 10  4  3   mar  mon  87.6   52.2  103.8   5.0  11.0  46   5.8   0.0    36.85
# 11  2  2   jul  fri  88.3  150.3  309.9   6.8  13.4  79   3.6   0.0    37.02
# 12  6  4   sep  tue  91.0  129.5  692.6   7.0  18.7  43   2.7   0.0   103.39
# 13  9  4   sep  tue  84.4   73.4  671.9   3.2  24.3  36   3.1   0.0   105.66
# 14  4  5   sep  sat  92.5  121.1  674.4   8.6  17.7  25   3.1   0.0   154.88
# 15  8  6   aug  sun  91.4  142.4  601.4  10.6  19.6  41   5.8   0.0   196.48
# 16  2  2   sep  sat  92.5  121.1  674.4   8.6  18.2  46   1.8   0.0   200.94
# 17  1  2   sep  tue  91.0  129.5  692.6   7.0  18.8  40   2.2   0.0   212.88
# 18  6  5   sep  sat  92.5  121.1  674.4   8.6  25.1  27   4.0   0.0  1090.84

# %% [markdown]
# **validate types**
#
# We need to make sure that the types in the columns are what we are expecting.

# %%
print(data_frame.dtypes)
# Out:
# X          int64
# Y          int64
# month     object
# day       object
# FFMC     float64
# DMC      float64
# DC       float64
# ISI      float64
# temp     float64
# RH         int64
# wind     float64
# rain     float64
# area     float64
# dtype: object

# %% [markdown]
# A dataset can have one or more named pipelines. Each pipeline is a chain of Python functions that transform the dataset.  In the next step, create a pipeline named "prep".

# %%
pipeline = data_set.pipeline('prep') # create or retrieve the pipline named 'prep'
pipeline.reset() # removes any previous steps or context for this pipeline

# %% [markdown]
# One pipeline step can be used to add a new column.
#
# This [dataset](http://piano.dsi.uminho.pt/~pcortez/fires.pdf) uses components from the Fire Weather Index to make predictions. One element, the Build Up Index (BUI) is based on a relation of two other columns and is omitted. This step adds that missing element.

# %%
def normalize(pipeline, df):
    cols = ["DMC", "DC", "area", "X", "Y", "FFMC", "temp"]
    df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')

pipeline.add_step(normalize)

# %%
def add_bui(pipeline, df):
    df['BUI'] = (0.8 * df['DMC'] * df['DC'])/(df['DMC'] + 0.4 * df['DC'])

pipeline.add_step(add_bui)

# %% [markdown]
# In the preceeding code, the pipeline step functions require a pipeline and a dataframe parameter. The [pandas DataFrame](https://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe) provides a rich set of functions for operating on table data.
#
# A pipeline step may be used to modify a column.
#
# The dataset's documentation says that the last column, __area__, is skewed towards zero and should be adjusted logarithmically "to improve regression results for right-skewed targets".

# %%
def fix_area(pipeline, df):
    df['area'] = df['area'].map(lambda a: math.log1p(a))
    
pipeline.add_step(fix_area)

# %% [markdown]
# ### Running the Pipeline
# After all the steps are added, you can call `run` on the pipeline. This invokes each of the steps in order and returns a transformed DataFrame instance.

# %%
data_frame = pipeline.run(data_frame)
# Out:
# running pipeline [prep]:
# > normalize
# > add_bui
# > fix_area

# %% [markdown]
# You can verify what your pipeline did here:

# %%
data_frame.dtypes
# Out:
# X          int64
# Y          int64
# month     object
# day       object
# FFMC     float64
# DMC      float64
# DC       float64
# ISI      float64
# temp     float64
# RH         int64
# wind     float64
# rain     float64
# area     float64
# BUI      float64
# dtype: object

# %% [markdown]
# Here you can visualize your data

# %%
def draw_graphs(data_set, data_frame, attribute):

    v = data_set.visuals(data_frame)
    v.show_corr_heatmap()
    v.show_corr(attribute)
    v.show_corr_pairs(attribute)
    v.show_dist(attribute)
    v.show_probplot(attribute)

# %%
draw_graphs(data_set, data_frame, 'area')

# %% [markdown]
# Lets save our pipeline for later use

# %%
pipeline.to_camel()
# Out:
# {'name': 'prep',
#  'steps': [{'name': 'normalize',
#    'function': {'name': 'normalize',
#     'code': '...',
#     'type': 'inline'}},
#   {'name': 'add_bui',
#    'function': {'name': 'add_bui',
#     'code': '...',
#     'type': 'inline'}},
#   {'name': 'fix_area',
#    'function': {'name': 'fix_area',
#     'code': '...',
#     'type': 'inline'}}],
#  'dependencies': [],
#  'context': {}}

# %%
data_set.save()

# %% [markdown]
# **Running the pipeline on a new dataset in Cortex Remote**
#
# We have added metadata to our local sample dataset, now we want to use this pipeline on the full dataset and move it to cortex remote

# %%
# Create a non-local Builder instance
from cortex.builder.dataset_builder import DatasetBuilder
cortex = Cortex.client()
builder = cortex.builder()

# %%
# to help with making this dataset distinct in class we will use an input generator here for the dataset name.  
# This variable will be stored throughout this example.
dataset_forestfire = input("namespace/dataset name")
    
data_set = builder.dataset(dataset_name_ff).title('Forest Fire Data')\
    .from_csv('data/forestfires.csv').build()
# Create a pandas DataFrame to view the last few lines of the dataset
data_frame = data_set.as_pandas()
data_frame.tail(20)
# Out:
# namespace/dataset name surface/forestfiresfull
# file version not found, pushing to remote storage: /cortex/datasets/surface/forest_fires/7736d4cedf4fab87e882470be3115051.csv
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH wind rain   area
# 497  3  4   aug  tue  96.1  181.1  671.2  14.3  32.3  27  2.2  0.0  14.68
# 498  6  5   aug  tue  96.1  181.1  671.2  14.3  33.3  26  2.7  0.0  40.54
# 499  7  5   aug  tue  96.1  181.1  671.2  14.3  27.3  63  4.9  6.4  10.82
# 500  8  6   aug  tue  96.1  181.1  671.2  14.3  21.6  65  4.9  0.8    0.0
# 501  7  5   aug  tue  96.1  181.1  671.2  14.3  21.6  65  4.9  0.8    0.0
# 502  4  4   aug  tue  96.1  181.1  671.2  14.3  20.7  69  4.9  0.4    0.0
# 503  2  4   aug  wed  94.5  139.4  689.1  20.0  29.2  30  4.9  0.0   1.95
# 504  4  3   aug  wed  94.5  139.4  689.1  20.0  28.9  29  4.9  0.0  49.59
# 505  1  2   aug  thu  91.0  163.2  744.4  10.1  26.7  35  1.8  0.0    5.8
# 506  1  2   aug  fri  91.0  166.9  752.6   7.1  18.5  73  8.5  0.0    0.0
# 507  2  4   aug  fri  91.0  166.9  752.6   7.1  25.9  41  3.6  0.0    0.0
# 508  1  2   aug  fri  91.0  166.9  752.6   7.1  25.9  41  3.6  0.0    0.0
# 509  5  4   aug  fri  91.0  166.9  752.6   7.1  21.1  71  7.6  1.4   2.17
# 510  6  5   aug  fri  91.0  166.9  752.6   7.1  18.2  62  5.4  0.0   0.43
# 511  8  6   aug  sun  81.6   56.7  665.6   1.9  27.8  35  2.7  0.0    0.0
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32  2.7  0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71  5.8  0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70  6.7  0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42  4.0  0.0    0.0
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31  4.5  0.0    0.0

# %% [markdown]
# We'll take a look at the pipeline camel spec here

# %%
pipeline.to_camel()
# Out:
# {'name': 'prep',
#  'steps': [{'name': 'normalize',
#    'function': {'name': 'normalize',
#     'code': '...',
#     'type': 'inline'}},
#   {'name': 'add_bui',
#    'function': {'name': 'add_bui',
#     'code': '...',
#     'type': 'inline'}},
#   {'name': 'fix_area',
#    'function': {'name': 'fix_area',
#     'code': '...',
#     'type': 'inline'}}],
#  'dependencies': [],
#  'context': {}}

# %%
print(pipeline)
# Out:
# <cortex.pipeline.Pipeline object at 0x000001B77B990588>

# %%
remote_pipeline = data_set.pipeline('prep') # create or retrieve the pipeline named 'prep'
remote_pipeline.from_pipeline(pipeline)
pipeline.reset() # removes any previous steps or context for this pipeline

# %%
remote_pipeline.run(data_frame)
# Out:
# running pipeline [prep]:
# > normalize
# > add_bui
# > fix_area
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH wind rain      area  \
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51  6.7  0.0  0.000000
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33  0.9  0.0  0.000000
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33  1.3  0.0  0.000000
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97  4.0  0.2  0.000000
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99  1.8  0.0  0.000000
# 5    8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29  5.4  0.0  0.000000
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27  3.1  0.0  0.000000
# 7    8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86  2.2  0.0  0.000000
# 8    8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63  5.4  0.0  0.000000
# 9    7  5   sep  sat  92.5   88.0  698.6   7.1  22.8  40  4.0  0.0  0.000000
# 10   7  5   sep  sat  92.5   88.0  698.6   7.1  17.8  51  7.2  0.0  0.000000
# 11   7  5   sep  sat  92.8   73.2  713.0  22.6  19.3  38  4.0  0.0  0.000000
# 12   6  5   aug  fri  63.5   70.8  665.3   0.8  17.0  
# 501  7  5   aug  tue  96.1  181.1  671.2  14.3  21.6  65  4.9  0.8  0.000000
# 502  4  4   aug  tue  96.1  181.1  671.2  14.3  20.7  69  4.9  0.4  0.000000
# 503  2  4   aug  wed  94.5  139.4  689.1  20.0  29.2  30  4.9  0.0  1.081805
# 504  4  3   aug  wed  94.5  139.4  689.1  20.0  28.9  29  4.9  0.0  3.923754
# 505  1  2   aug  thu  91.0  163.2  744.4  10.1  26.7  35  1.8  0.0  1.916923
# 506  1  2   aug  fri  91.0  166.9  752.6   7.1  18.5  73  8.5  0.0  0.000000
# 507  2  4   aug  fri  91.0  166.9  752.6   7.1  25.9  41  3.6  0.0  0.000000
# 508  1  2   aug  fri  91.0  166.9  752.6   7.1  25.9  41  3.6  0.0  0.000000
# 509  5  4   aug  fri  91.0  166.9  752.6   7.1  21.1  71  7.6  1.4  1.153732
# 510  6  5   aug  fri  91.0  166.9  752.6   7.1  18.2  62  5.4  0.0  0.357674
# 511  8  6   aug  sun  81.6   56.7  665.6   1.9  27.8  35  2.7  0.0  0.000000
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32  2.7  0.0  2.006871
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71  5.8  0.0  4.012592
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70  6.7  0.0  2.498152
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42  4.0  0.0  0.000000
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31  4.5  0.0  0.000000
#
#             BUI
# 0     30.921902
# 1     62.529409
# 2     75.406720
# 3     32.108865
# 4     45.501063
# 5    118.720570
# 6    122.752218
# 7    182.015602
# 8    176.497663
# 9    133.848901
# 10   133.848901
# 11   116.499107
# 12   111.844331
# 13   173.208178
# 14   180.581265
# 15   188.963689
# 16    33.971110
# 17    58.391209
# 18    28.108431
# 19    32.132126
# 20   176.497663
# 21   123.529520
# 22    87.396483
# 23   146.314761
# 24   175.732428
# 25   178.899854
# 26   163.608829
# 27   173.208178
# 28   193.366319
# 29   197.449707
# ..          ...
# 487  178.509025
# 488  178.509025
# 489  178.509025
# 490  178.509025
# 491  188.951698
# 492  194.650593
# 493  194.650593
# 494  200.288699
# 495  211.068829
# 496  211.068829
# 497  216.298447
# 498  216.298447
# 499  216.298447
# 500  216.298447
# 501  216.298447
# 502  216.298447
# 503  185.159098
# 504  185.159098
# 505  210.840125
# 506  214.743668
# 507  214.743668
# 508  214.743668
# 509  214.743668
# 510  214.743668
# 511   93.489862
# 512   93.489862
# 513   93.489862
# 514   93.489862
# 515  183.211595
# 516    5.605954
#
# [517 rows x 14 columns]

# %%
def draw_graphs(data_set, data_frame, attribute):

    v = data_set.visuals(data_frame)
    v.show_corr_heatmap()
    v.show_corr(attribute)
    v.show_corr_pairs(attribute)
    v.show_dist(attribute)
    v.show_probplot(attribute)

# %%
draw_graphs(data_set, data_frame, 'area')

# %%
print(data_frame.dtypes)
# Out:
# X          int64
# Y          int64
# month     object
# day       object
# FFMC     float64
# DMC      float64
# DC       float64
# ISI       object
# temp     float64
# RH        object
# wind      object
# rain      object
# area     float64
# BUI      float64
# dtype: object

# %%
tp.to_camel()
# Out:
# {'name': 'test_pipeline', 'steps': [], 'dependencies': [], 'context': {}}
